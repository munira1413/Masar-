# %% [markdown]
# <a href="https://colab.research.google.com/github/munira1413/Masar-/blob/main/HW2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/processed.cleveland.data.csv' )

# %%
df
# Out:
#      63;1;1;145;233;1;2;150;0;2.3;3;0;6;0
# 0    67;1;4;160;286;0;2;108;1;1.5;2;3;3;2
# 1    67;1;4;120;229;0;2;129;1;2.6;2;2;7;1
# 2    37;1;3;130;250;0;0;187;0;3.5;3;0;3;0
# 3    41;0;2;130;204;0;2;172;0;1.4;1;0;3;0
# 4    56;1;2;120;236;0;0;178;0;0.8;1;0;3;0
# ..                                    ...
# 297  45;1;1;110;264;0;0;132;0;1.2;2;0;7;1
# 298  68;1;4;144;193;1;0;141;0;3.4;2;2;7;2
# 299  57;1;4;130;131;0;0;115;1;1.2;2;1;7;3
# 300    57;0;2;130;236;0;2;174;0;0;2;1;3;1
# 301    38;1;3;138;175;0;0;173;0;0;1;?;3;0
#
# [302 rows x 1 columns]

# %%
df.head()
# Out:
#    63;1;1;145;233;1;2;150;0;2.3;3;0;6;0
# 0  67;1;4;160;286;0;2;108;1;1.5;2;3;3;2
# 1  67;1;4;120;229;0;2;129;1;2.6;2;2;7;1
# 2  37;1;3;130;250;0;0;187;0;3.5;3;0;3;0
# 3  41;0;2;130;204;0;2;172;0;1.4;1;0;3;0
# 4  56;1;2;120;236;0;0;178;0;0.8;1;0;3;0

# %%
df.tail()
# Out:
#      63;1;1;145;233;1;2;150;0;2.3;3;0;6;0
# 297  45;1;1;110;264;0;0;132;0;1.2;2;0;7;1
# 298  68;1;4;144;193;1;0;141;0;3.4;2;2;7;2
# 299  57;1;4;130;131;0;0;115;1;1.2;2;1;7;3
# 300    57;0;2;130;236;0;2;174;0;0;2;1;3;1
# 301    38;1;3;138;175;0;0;173;0;0;1;?;3;0

# %%
import pandas as pd

#define the faile paths
data_file_path='/content/processed.cleveland.data.csv'
headers_file_path='/content/headers.csv'

#read the headrs
headers = pd.read_csv( headers_file_path, header=None)
headers = headers.squeeze().tolist () #convert to list

#read the dataset with the headres
df=pd.read_csv(data_file_path,header=None,names=headers)

# %%
df
# Out:
#                                       age  sex  cp  trestbps  chol  fbs  \
# 0    63;1;1;145;233;1;2;150;0;2.3;3;0;6;0  NaN NaN       NaN   NaN  NaN
# 1    67;1;4;160;286;0;2;108;1;1.5;2;3;3;2  NaN NaN       NaN   NaN  NaN
# 2    67;1;4;120;229;0;2;129;1;2.6;2;2;7;1  NaN NaN       NaN   NaN  NaN
# 3    37;1;3;130;250;0;0;187;0;3.5;3;0;3;0  NaN NaN       NaN   NaN  NaN
# 4    41;0;2;130;204;0;2;172;0;1.4;1;0;3;0  NaN NaN       NaN   NaN  NaN
# ..                                    ...  ...  ..       ...   ...  ...
# 298  45;1;1;110;264;0;0;132;0;1.2;2;0;7;1  NaN NaN       NaN   NaN  NaN
# 299  68;1;4;144;193;1;0;141;0;3.4;2;2;7;2  NaN NaN       NaN   NaN  NaN
# 300  57;1;4;130;131;0;0;115;1;1.2;2;1;7;3  NaN NaN       NaN   NaN  NaN
# 301    57;0;2;130;236;0;2;174;0;0;2;1;3;1  NaN NaN       NaN   NaN  NaN
# 302    38;1;3;138;175;0;0;173;0;0;1;?;3;0  NaN NaN       NaN   NaN  NaN
#
#      restecg  thalach  exang  oldpeak  slope  ca  thal  num
# ...
